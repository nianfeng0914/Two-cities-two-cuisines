# %%
import requests 
import bs4 as bs 

from time import sleep
from time import time
from random import randint

import pandas as pd

# %%
headers = {'Host': 'www.dianping.com',
    'Referer': 'http://www.dianping.com/shop/22711693',
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/535.19',
    'Accept-Encoding': 'gzip'}
source = requests.get('https://www.dianping.com/search/keyword/8/0_%E5%B7%9D%E8%8F%9C',headers=headers) 

print(source)
# Out:
# <Response [200]>

# %%
soup = bs.BeautifulSoup(source.content, 'html.parser')

# %%
numbers = soup.find_all('div',class_='bread J_bread')

# %%
print(numbers)
# Out:
# [<div class="bread J_bread">
# <a href="/chengdu">
# <span>首页</span>
# </a>
# <span class="path"></span>
# <span>共为您找到19094个"川菜"相关商户</span>
# </div>]

# %%
for number in numbers:
    amount = number.select('span:nth-of-type(3)')
    print(amount)
# Out:
# [<span>共为您找到19094个"川菜"相关商户</span>]

# %%
titles = []
kouweis = []
huanjings = []
fuwus = []
places = []

pages = [str(i) for i in range(1,51)] 

headers = {'Host': 'www.dianping.com',
    'Referer': 'http://www.dianping.com/shop/22711693',
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/535.19',
    'Accept-Encoding': 'gzip'}

for page in pages:
    
    source1 = requests.get('http://www.dianping.com/chengdu/ch10/g102o2p' + page,headers=headers)

    sleep(randint(1,3))

    page_html = bs.BeautifulSoup(source1.content, 'html.parser')

    containers = page_html.find_all('div',class_='tit') 

    for container in containers:

        for title in container.find_all('h4'): 
            titles.append(title.text.strip())

    kouweiss = page_html.find_all('span',class_='comment-list') 

    for kouweisss in kouweiss:
            kouwei = kouweisss.select('b:nth-of-type(1)')
            for kouwei_text in kouwei:
                kouwei_txt = kouwei_text.get_text()
            kouweis.append(kouwei_txt)

    huanjingss = page_html.find_all('span',class_='comment-list') 

    for huanjingsss in huanjingss:
            huanjing = huanjingsss.select('b:nth-of-type(2)')
            for huanjing_text in huanjing:
                huanjing_txt = huanjing_text.get_text()
            huanjings.append(huanjing_txt)

    fuwuss = page_html.find_all('span',class_='comment-list') 

    for fuwusss in fuwuss:
            fuwu = fuwusss.select('b:nth-of-type(3)')
            for fuwu_text in fuwu:
                fuwu_txt = fuwu_text.get_text()
            fuwus.append(fuwu_txt)

    placess = page_html.find_all('div',class_='tag-addr') 

    for placesss in placess:
        place = placesss.select('a:nth-of-type(2)')
        for place_text in place:
            place_text = place_text.get('href')
        places.append(place_text)
        

print(titles)
print(kouweis)
print(huanjings)
print(fuwus)
print(places)

# %%
titles = []

pages = [str(i) for i in range(1,51)] 

headers = {'Host': 'www.dianping.com',
    'Referer': 'http://www.dianping.com/shop/22711693',
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/535.19',
    'Accept-Encoding': 'gzip'}

for page in pages:
    
    source1 = requests.get('http://www.dianping.com/chengdu/ch10/g102o2p' + page,headers=headers)

    sleep(randint(1,3))

    page_html = bs.BeautifulSoup(source1.content, 'html.parser')

    containers = page_html.find_all('div',class_='tit') 

    for container in containers:

        for title in container.find_all('h4'): 
            titles.append(title.text.strip())


print(titles)
# Out:

    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/535.19',
    'Accept-Encoding': 'gzip'}

for page in pages:
    
    source1 = requests.get('http://www.dianping.com/chengdu/ch10/g102o2p' + page,headers=headers)

    sleep(randint(1,3))

    page_html = bs.BeautifulSoup(source1.content, 'html.parser')

    kouweiss = page_html.find_all('span',class_='comment-list') 

    for kouweisss in kouweiss:
            kouwei = kouweisss.select('b:nth-of-type(1)')
            for kouwei_text in kouwei:
                kouwei_txt = kouwei_text.get_text()
            kouweis.append(kouwei_txt)

print(kouweis)
# Out:
# ['8.5', '8.9', '8.9', '9.0', '9.0', '9.1', '9.1', '7.9', '9.0', '9.0', '9.0', '9.1', '8.8', '9.0', '8.8', '8.5', '8.6', '8.6', '9.1', '9.2', '9.1', '8.5', '8.7', '8.8', '8.2', '8.8', '7.6', '7.7', '8.3', '9.0', '9.0', '7.9', '7.6', '7.7', '9.0', '8.8', '8.0', '8.0', '8.6', '8.9', '8.3', '8.9', '7.6', '9.0', '8.4', '8.8', '7.9', '8.6', '7.3', '8.0', '9.2', '8.9', '8.2', '9.3', '8.0', '7.9', '8.2', '8.7', '7.3', '8.2', '8.8', '7.8', '8.9', '8.4', '8.5', '8.1', '9.1', '7.5', '9.0', '7.9', '8.2', '8.5', '8.7', '8.8', '8.3', '8.0', '8.6', '9.0', '9.1', '8.5', '7.7', '9.0', '8.3', '8.6', '8.2', '8.8', '7.8', '8.6', '8.0', '8.1', '7.7', '8.8', '9.1', '8.0', '8.5', '8.2', '7.5', '8.5', '8.7', '8.2', '7.5', '8.8', '8.8', '8.3', '8.6', '9.1', '8.1', '8.0', '7.6', '8.1', '8.7', '9.1', '8.8', '8.3', '8.3', '8.3', '8.7', '8.7', '8.8', '8.9', '8.3', '8.3', '8.7', '8.3', '8.3', '8.3', '8.4', '7.5', '8.3', '7.6', '8.5', '8.6', '9.0', '8.5', '8.8', '8.4', '8.0', '8.6', '9.0', '7.9', '7.9', '8.4', '8.9', '8.6', '8.8', '7.6', '8.2', '8.7', '8.0', '8.1', '9.0', '8.1', '9.1', '8.5', '7.7', '9.0', '8.5', '8.5', '9.0', '8.6', '8.4', '9.1', '9.1', '7.9', '7.9', '8.6', '8.6', '7.3', '8.9', '8.4', '8.4', '9.0', '7.8', '8.2', '8.0', '8.5', '8.5', '8.0', '9.1', '8.9', '8.2', '9.0', '8.0', '8.7', '7.8', '7.8', '8.2', '7.6', '8.8', '8.0', '7.9', '8.2', '6.9', '9.0', '8.4', '8.1', '8.1', '8.0', '7.6', '7.7', '8.7', '8.7', '8.7', '8.4', '8.1', '9.0', '9.2', '8.4', '8.1', '9.0', '8.4', '8.3', '8.8', '8.5', '7.4', '8.7', '8.2', '9.0', '9.0', '8.5', '7.8', '8.2', '8.5', '7.8', '8.6', '7.8', '8.6', '8.6', '7.9', '7.9', '8.3', '9.1', '8.9', '8.5', '8.6', '8.4', '7.8', '8.7', '8.0', '7.4', '8.5', '9.0', '8.3', '7.5', '8.5', '8.7', '8.0', '8.2', '8.9', '9.0', '7.5', '8.2', '7.1', '8.7', '8.8', '8.5', '8.3', '8.8', '8.8', '7.9', '7.6', '9.0', '8.2', '8.4', '8.5', '8.7', '8.7', '9.1', '7.2', '7.3', '7.5', '8.2', '7.2', '8.0', '8.8', '7.5', '8.3', '8.6', '8.2', '7.2', '7.8', '8.

    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/535.19',
    'Accept-Encoding': 'gzip'}

for page in pages:
    
    source1 = requests.get('http://www.dianping.com/chengdu/ch10/g102o2p' + page,headers=headers)

    sleep(randint(1,3))

    page_html = bs.BeautifulSoup(source1.content, 'html.parser')

    huanjingss = page_html.find_all('span',class_='comment-list') 

    for huanjingsss in huanjingss:
            huanjing = huanjingsss.select('b:nth-of-type(2)')
            for huanjing_text in huanjing:
                huanjing_txt = huanjing_text.get_text()
            huanjings.append(huanjing_txt)

print(huanjings)
# Out:
# ['9.1', '7.6', '8.8', '8.8', '9.1', '9.0', '8.7', '8.4', '9.1', '9.0', '8.9', '9.0', '8.9', '8.5', '8.9', '9.2', '9.0', '8.1', '8.7', '9.3', '8.3', '8.9', '9.1', '7.0', '6.7', '8.1', '8.7', '8.3', '9.0', '9.1', '9.0', '8.5', '7.6', '9.1', '8.7', '8.8', '7.4', '8.6', '9.0', '8.7', '8.9', '8.7', '8.5', '9.0', '9.1', '8.0', '7.6', '8.3', '8.8', '8.6', '9.2', '9.0', '9.2', '9.4', '8.6', '7.0', '7.2', '9.1', '7.8', '9.1', '8.0', '8.5', '9.0', '8.6', '8.9', '8.5', '9.1', '6.5', '9.2', '8.9', '8.0', '9.0', '7.7', '8.8', '9.2', '8.7', '9.1', '9.1', '8.6', '8.6', '9.1', '9.2', '8.1', '9.0', '8.7', '9.0', '7.5', '8.7', '8.9', '7.3', '9.0', '8.5', '9.1', '9.1', '8.9', '9.0', '8.3', '7.4', '9.1', '8.7', '8.6', '8.7', '8.2', '7.8', '9.1', '9.0', '8.4', '8.8', '8.3', '5.9', '9.1', '9.2', '8.4', '9.1', '8.9', '8.5', '8.6', '9.2', '9.0', '9.0', '8.9', '8.5', '8.8', '8.5', '8.8', '8.8', '8.2', '7.7', '6.7', '8.3', '8.8', '9.0', '9.1', '9.0', '7.1', '7.6', '9.0', '9.1', '8.9', '9.0', '8.6', '6.5', '9.1', '9.0', '8.2', '8.7', '8.3', '8.9', '7.4', '7.8', '9.0', '8.2', '9.3', '8.3', '7.1', '9.1', '8.3', '8.5', '9.0', '8.4', '8.7', '9.1', '9.1', '8.7', '8.9', '8.7', '8.4', '6.9', '9.2', '8.9', '9.0', '9.1', '8.7', '8.0', '8.0', '8.4', '8.4', '8.1', '9.1', '8.4', '7.6', '9.0', '8.5', '9.0', '8.3', '7.5', '7.9', '7.8', '8.7', '8.8', '9.0', '8.8', '7.5', '8.5', '8.9', '8.9', '7.9', '8.1', '8.4', '7.3', '8.7', '8.1', '8.4', '8.4', '7.8', '9.1', '8.0', '8.1', '8.9', '9.0', '9.1', '9.0', '8.9', '9.1', '7.6', '8.8', '8.8', '9.1', '8.4', '8.6', '8.8', '8.0', '8.9', '8.6', '8.9', '8.5', '9.2', '8.5', '8.7', '8.7', '8.9', '8.6', '9.0', '8.1', '9.0', '7.5', '9.0', '8.6', '8.6', '7.4', '8.6', '8.9', '8.3', '7.9', '8.4', '8.7', '8.0', '8.9', '8.8', '9.0', '8.1', '8.2', '7.4', '9.1', '8.5', '8.8', '6.7', '8.

    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/535.19',
    'Accept-Encoding': 'gzip'}

for page in pages:
    
    source1 = requests.get('http://www.dianping.com/chengdu/ch10/g102o2p' + page,headers=headers)

    sleep(randint(1,3))

    page_html = bs.BeautifulSoup(source1.content, 'html.parser')

    fuwuss = page_html.find_all('span',class_='comment-list') 

    for fuwusss in fuwuss:
            fuwu = fuwusss.select('b:nth-of-type(3)')
            for fuwu_text in fuwu:
                fuwu_txt = fuwu_text.get_text()
            fuwus.append(fuwu_txt)

print(fuwus)
# Out:
# ['8.9', '8.6', '9.0', '8.9', '9.1', '9.1', '8.6', '7.8', '9.0', '9.2', '8.5', '9.1', '8.7', '9.1', '8.5', '9.1', '8.3', '8.2', '9.1', '9.3', '9.0', '8.5', '9.2', '7.7', '7.3', '8.5', '7.9', '8.0', '8.7', '9.3', '9.1', '8.0', '7.2', '8.1', '9.1', '8.5', '7.7', '7.8', '8.7', '8.8', '8.8', '8.9', '8.0', '8.9', '8.2', '8.8', '6.7', '8.5', '7.9', '8.3', '9.2', '9.0', '7.9', '9.3', '8.0', '7.2', '7.4', '9.0', '6.6', '9.1', '8.3', '7.8', '8.8', '8.5', '8.2', '7.9', '9.1', '7.2', '9.2', '8.4', '7.7', '9.1', '8.1', '8.9', '8.5', '8.2', '8.5', '9.0', '9.0', '8.7', '8.4', '9.2', '7.7', '8.3', '7.7', '8.9', '7.7', '8.0', '7.7', '7.9', '8.0', '8.3', '9.1', '7.7', '8.9', '8.9', '8.0', '7.6', '8.6', '8.2', '7.6', '8.5', '9.0', '7.6', '8.8', '9.0', '7.6', '7.8', '7.6', '6.9', '9.0', '9.3', '8.3', '8.9', '8.2', '7.9', '8.6', '9.1', '9.1', '8.9', '8.6', '8.8', '8.6', '8.3', '7.8', '8.2', '8.4', '7.3', '7.5', '8.2', '8.8', '8.6', '9.3', '8.7', '7.3', '7.8', '8.2', '8.8', '8.7', '8.2', '7.9', '6.9', '9.1', '8.8', '8.1', '8.4', '8.0', '8.4', '7.3', '7.3', '9.1', '7.9', '9.0', '8.3', '7.2', '9.0', '8.4', '8.6', '9.0', '8.4', '8.3', '9.0', '9.1', '7.6', '8.0', '8.1', '8.5', '7.0', '9.1', '8.6', '8.7', '9.1', '7.7', '7.8', '7.8', '8.1', '8.4', '7.8', '9.2', '8.3', '7.8', '9.0', '8.7', '8.9', '7.6', '7.4', '8.0', '7.6', '8.7', '8.2', '8.1', '8.6', '6.9', '8.7', '8.4', '9.1', '7.4', '7.7', '8.0', '7.6', '8.7', '8.5', '8.8', '9.1', '7.9', '8.9', '8.6', '8.2', '8.2', '9.0', '9.0', '8.2', '8.7', '9.0', '7.5', '9.1', '8.8', '9.0', '8.3', '8.8', '7.9', '8.1', '8.1', '8.1', '8.8', '8.1', '8.6', '8.6', '8.4', '8.2', '8.2', '9.1', '8.9', '7.8',
# %%
places = []

pages = [str(i) for i in range(1,51)] 

headers = {'Host': 'www.dianping.com',
    'Referer': 'http://www.dianping.com/shop/22711693',
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/535.19',
    'Accept-Encoding': 'gzip'}

for page in pages:
    
    source1 = requests.get('http://www.dianping.com/chengdu/ch10/g102o2p' + page,headers=headers)

    sleep(randint(1,3))

    page_html = bs.BeautifulSoup(source1.content, 'html.parser')

    placess = page_html.find_all('div',class_='tag-addr') 

    for placesss in placess:
        place = placesss.select('a:nth-of-type(2)')
        for place_text in place:
            place_text = place_text.get('href')
        places.append(place_text)
        
print(places)
# Out:
# ['http://www.dianping.com/chengdu/ch10/r1577', 'http://www.dianping.com/chengdu/ch10/r7767', 'http://www.dianping.com/chengdu/ch10/r1577', 'http://www.dianping.com/chengdu/ch10/r5894', 'http://www.dianping.com/chengdu/ch10/r1593', 'http://www.dianping.com/chengdu/ch10/r1577', 'http://www.dianping.com/chengdu/ch10/r12365', 'http://www.dianping.com/chengdu/ch10/r7764', 'http://www.dianping.com/chengdu/ch10/r1577', 'http://www.dianping.com/chengdu/ch10/r7763', 'http://www.dianping.com/chengdu/ch10/r1578', 'http://www.dianping.com/chengdu/ch10/r1578', 'http://www.dianping.com/chengdu/ch10/r1593', 'http://www.dianping.com/chengdu/ch10/r1578', 'http://www.dianping.com/chengdu/ch10/r1577', 'http://www.dianping.com/chengdu/ch10/r7767', 'http://www.dianping.com/chengdu/ch10/r1583', 'http://www.dianping.com/chengdu/ch10/r7767', 'http://www.dianping.com/chengdu/ch10/r1596', 'http://www.dianping.com/chengdu/ch10/r7764', 'http://www.dianping.com/chengdu/ch10/r1577', 'http://www.dianping.com/chengdu/ch10/r7949', 'http://www.dianping.com/chengdu/ch10/r1592', 'http://www.dianping.com/chengdu/ch10/r12372', 'http://www.dianping.com/chengdu/ch10/r7770', 'http://www.dianping.com/chengdu/ch10/r1577', 'http://www.dianping.com/chengdu/ch10/r7767', 'http://www.dianping.com/chengdu/ch10/r7949', 'http://www.dianping.com/chengdu/ch10/r7764', 'http://www.dianping.com/chengdu/ch10/r1596', 'http://www.dianping.com/chengdu/ch10/r7767', 'http://www.dianping.com/chengdu/ch10/r1577', 'http://www.dianping.com/chengdu/ch10/r70146', 'http://www.dianping.com/chengdu/ch10/r7766', 'http://www.dianping.com/chengdu/ch10/r1599', 'http://www.dianping.com/chengdu/ch10/r1577', 'http://www.dianping.com/chengdu/ch10/r1597', 'http://www.dianping.com/chengdu/ch10/r7767', 'http://www.dianping.com/chengdu/ch10/r1577', 'http://www.dianping.com/chengdu/ch10/r5894', 'http://www.dianping.com/chengdu/ch10/r7949', 'http://www.dianping.com/chengdu/ch10/r1974', 'http://www.dianping.com/chengdu/ch10/r1577', 'http://www.dianping.com/chengdu/ch10/r1591', 'http://www.dianping.com/chengdu/ch10/r7949', 'http://www.dianping.com/chengdu/ch10/r1578', 'http://www.dianping.com/chengdu/ch10/r1604', 'http://www.dianping.com/chengdu/ch10/r7760', 'http://www.dianping.com/chengdu/ch10/r1577', 'http://www.dianping.com/chengdu/ch10/r7760', 'http://www.dianping.com/chengdu/ch10/r7770', 'http://www.dianping.com/chengdu/ch10/r1593', 'http://www.dianping.com/chengdu/ch10/r1583', 'http://www.dianping.com/chengdu/ch10/r7949', 'http://www.dianping.com/chengdu/ch10/r85538', 'http://www.dianping.com/chengdu/ch10/r1590', 'http://www.dianping.com/chengdu/ch10/r1597', 'http://www.dianping.com/chengdu/ch10/r7949', 'http://www.dianping.com/chengdu/ch10/r85837', 'http://www.dianping.com/chengdu/ch10/r5893', 'http://www.dianping.com/chengdu/ch10/r7767', 'http://www.dianping.com/chengdu/ch10/r7949', 'http://www.dianping.com/chengdu/ch10/r7949', 'http://www.dianping.com/chengdu/ch10/r70146', 'http://www.dianping.com/chengdu/ch10/r7949', 'http://www.dianping.com/chengdu/ch10/r7767', 'http://www.dianping.com/chengdu/ch10/r7949', 'http://www.dianping.com/chengdu/ch10/r1577', 'http://www.dianping.com/chengdu/ch10/r1596', 'http://www.dianping.com/chengdu/ch10/r7949', 'http://www.dianping.com/chengdu/ch10/r1577', 'http://www.dianping.com/chengdu/ch10/r1596', 'http://www.dianping.com/chengdu/ch10/r7767', 'http://www.dianping.com/chengdu/ch10/r1593', 'http://www.dianping.com/chengdu/ch10/r1602', 'http://www.dianping.com/chengdu/ch10/r7949', 'http://www.dianping.com/chengdu/ch10/r7771', 'http://www.dianping.com/chengdu/ch10/r7766', 'http://www.dianping.com/chengdu/ch10/r1591', 'http://www.dianping.com/chengdu/ch10/r1583', 'http://www.dianping.com/chengdu/ch10/r12361', 'http://www.dianping.com/chengdu/ch10/r7767', 'http://www.dianping.com/chengdu/ch10/r9347', 'http://www.dianping.com/chengdu/ch10/r1586', 'http://www.dianping.com/chengdu/ch10/r7949', 'http://www.dianping.com/chengdu/ch10/r7767', 'http://www.dianping.com/chengdu/ch1 ...

# %%
shop = {
    '店名': titles,
    '口味': kouweis,
    '环境': huanjings,
    '服务': fuwus,
    '地区': places
}

# %%
pd_Shops_sichuan_chuancai = pd.DataFrame.from_dict(shop, orient ='index').transpose()

# %%
pd_Shops_sichuan_chuancai
# Out:
#                       店名    口味    环境    服务  \
# 0                马旺子·川小馆   8.5   9.1   8.9
# 1             成都吃客(奎星楼店)   8.9   7.6   8.6
# 2             成都吃客(致民路店)   8.9   8.8   9.0
# 3             饕林餐厅(春熙路店)   9.0   8.8   8.9
# 4             饕林餐厅(武侯祠店)   9.0   9.1   9.1
# 5          饕林·约饭(太古里小院店)   9.1   9.0   9.1
# 6         鸡毛店(温江老字号李家沱店)   9.1   8.7   8.6
# 7           柴门饭儿(远洋太古里店)   7.9   8.4   7.8
# 8      汤公汤婆煲汤治愈所(IFS旗舰店)   9.0   9.1   9.0
# 748                 竹韵餐厅   8.8   9.1   8.6
# 749        百姓百味家乡川菜(武侯店)  None  None  None
#
#                                                  地区
# 0        http://www.dianping.com/chengdu/ch10/r1577
# 1        http://www.dianping.com/chengdu/ch10/r7767
# 2        http://www.dianping.com/chengdu/ch10/r1577
# 3        http://www.dianping.com/chengdu/ch10/r5894
# 4        http://www.dianping.com/chengdu/ch10/r1593
# 5        http://www.dianping.com/chengdu/ch10/r1577
# 6       http://www.dianping.com/chengdu/ch10/r12365
# 7        http://www.dianping.com/chengdu/ch10/r7764
# 8        http://www.dianping.com/chengdu/ch10/r1577
# 9        http://www.dianping.com/chengdu/ch10/r7763
# 10       http://www.dianping.com/chengdu/ch10/r1578
# 11       http://www.dianping.com/chengdu/ch10/r1578
# 12       http://www.dianping.com/chengdu/ch10/r1593
# 13       http://www.dianping.com/chengdu/ch10/r1578
# 14       http://www.dianping.com/chengdu/ch10/r1577
# 15       http://www.dianping.com/chengdu/ch10/r7767
# 16       http://www.dianping.com/chengdu/ch10/r1583
# 17       http://www.dianping.com/chengdu/ch10/r7767
# 18       http://www.dianping.com/chengdu/ch10/r1596
# 19       http://www.dianping.com/chengdu/ch10/r7764
# 20       http://www.dianping.com/chengdu/ch10/r1577
# 21       http://www.dianping.com/chengdu/ch10/r7949
# 22       http://www.dianping.com/chengdu/ch10/r1592
# 23      http://www.dianping.com/chengdu/ch10/r12372
# 24       http://www.dianping.com/chengdu/ch10/r7770
# 25       http://www.dianping.com/chengdu/ch10/r1577
# 26       http://www.dianping.com/chengdu/ch10/r7767
# 27       http://www.dianping.com/chengdu/ch10/r7949
# 28       http://www.dianping.com/chengdu/ch10/r7764
# 29       http://www.dianping.com/chengdu/ch10/r1596
# ..                                              ...
# 720      http://www.dianping.com/chengdu/ch10/r7949
# 721      http://www.dianping.com/chengdu/ch10/r7949
# 722     http://www.dianping.com/jintang/ch10/r27624
# 723      http://www.dianping.com/chengdu/ch10/r1596
# 724   http://www.dianping.com/shuangliu/ch10/r67287
# 725      http://www.dianping.com/chengdu/ch10/r1591
# 726      http://www.dianping.com/chengdu/ch10/r1588
# 727      http://www.dianping.com/chengdu/ch10/r1599
# 728      http://www.dianping.com/chengdu/ch10/r7949
# 729      http://www.dianping.com/chengdu/ch10/r1580
# 730     http://www.dianping.com/chengdu/ch10/r85538
# 731      http://www.dianping.com/chengdu/ch10/r1592
# 732      http://www.dianping.com/chengdu/ch10/r1590
# 733      http://www.dianping.com/chengdu/ch10/r7769
# 734      http://www.dianping.com/chengdu/ch10/r1972
# 735      http://www.dianping.com/chengdu/ch10/r1583
# 736      http://www.dianping.com/chengdu/ch10/r1586
# 737      http://www.dianping.com/chengdu/ch10/r1974
# 738      http://www.dianping.com/chengdu/ch10/r1972
# 739     http://www.dianping.com/chengdu/ch10/r30791
# 740      http://www.dianping.com/chengdu/ch10/r1583
# 741      http://www.dianping.com/chengdu/ch10/r1591
# 742      http://www.dianping.com/chengdu/ch10/r1578
# 743      http://www.dianping.com/chengdu/ch10/r8949
# 744  http://www.dianping.com/dujiangyan/ch10/r28900
# 745      http://www.dianping.com/chengdu/ch10/r1579
# 746   http://www.dianping.com/shuangliu/ch10/r30029
# 747      http://www.dianping.com/chengdu/ch10/r1579
# 748      http://www.dianping.com/chengdu/ch10/r8951
# 749     http://www.dianping.com/chengdu/ch10/r70611
#
# [750 rows x 5 columns]

# %%
pd_Shops_sichuan_chuancai.to_csv('Shops_sichuan_chuancai_50.csv')

# %%
df = pd.read_csv('Shops_sichuan_chuancai_50.csv')
df.head(5)
# Out:
#    Unnamed: 0          店名   口味   环境   服务  \
# 0           0     马旺子·川小馆  8.5  9.1  8.9
# 1           1  成都吃客(奎星楼店)  8.9  7.6  8.6
# 2           2  成都吃客(致民路店)  8.9  8.8  9.0
# 3           3  饕林餐厅(春熙路店)  9.0  8.8  8.9
# 4           4  饕林餐厅(武侯祠店)  9.0  9.1  9.1
#
#                                            地区
# 0  http://www.dianping.com/chengdu/ch10/r1577
# 1  http://www.dianping.com/chengdu/ch10/r7767
# 2  http://www.dianping.com/chengdu/ch10/r1577
# 3  http://www.dianping.com/chengdu/ch10/r5894
# 4  http://www.dianping.com/chengdu/ch10/r1593

# %%
gaoxin =[]
for i in df['地区']:
    if i.__contains__('http://www.dianping.com/chengdu/ch10/r7949'):
        gaoxin.append(True)
    else:
        gaoxin.append(False)

df['地区'][gaoxin]  = '高新区'
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
chunxi =[]
for i in df['地区']:
    if i.__contains__('http://www.dianping.com/chengdu/ch10/r1577'):
        chunxi.append(True)
    else:
        chunxi.append(False)

df['地区'][chunxi]  = '春熙路'
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
kuanzhai =[]
for i in df['地区']:
    if i.__contains__('http://www.dianping.com/chengdu/ch10/r7767'):
        kuanzhai.append(True)
    else:
        kuanzhai.append(False)

df['地区'][kuanzhai]  = '宽窄巷子'
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
yanshikou =[]
for i in df['地区']:
    if i.__contains__('http://www.dianping.com/chengdu/ch10/r5894'):
        yanshikou.append(True)
    else:
        yanshikou.append(False)

df['地区'][yanshikou]  = '盐市口'
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
wuhouci =[]
for i in df['地区']:
    if i.__contains__('http://www.dianping.com/chengdu/ch10/r1593'):
        wuhouci.append(True)
    else:
        wuhouci.append(False)

df['地区'][wuhouci]  = '武侯祠'
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
kehuabeilu =[]
for i in df['地区']:
    if i.__contains__('http://www.dianping.com/chengdu/ch10/r1592'):
        kehuabeilu.append(True)
    else:
        kehuabeilu.append(False)

df['地区'][kehuabeilu]  = '科华北路'
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
jinhuawanda =[]
for i in df['地区']:
    if i.__contains__('http://www.dianping.com/chengdu/ch10/r1601'):
        jinhuawanda.append(True)
    else:
        jinhuawanda.append(False)

df['地区'][jinhuawanda]  = '锦华万达'
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
tiaosanta =[]
for i in df['地区']:
    if i.__contains__('http://www.dianping.com/chengdu/ch10/r70146'):
        tiaosanta.append(True)
    else:
        tiaosanta.append(False)

df['地区'][tiaosanta]  = '跳伞塔'
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
dacisi =[]
for i in df['地区']:
    if i.__contains__('http://www.dianping.com/chengdu/ch10/r7764'):
        dacisi.append(True)
    else:
        dacisi.append(False)

df['地区'][dacisi]  = '大慈寺'
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
moziqiao =[]
for i in df['地区']:
    if i.__contains__('http://www.dianping.com/chengdu/ch10/r7771'):
        moziqiao.append(True)
    else:
        moziqiao.append(False)

df['地区'][moziqiao]  = '磨子桥'
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
guanghua =[]
for i in df['地区']:
    if i.__contains__('http://www.dianping.com/chengdu/ch10/r7769'):
        guanghua.append(True)
    else:
        guanghua.append(False)

df['地区'][guanghua]  = '光华'
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
renmin =[]
for i in df['地区']:
    if i.__contains__('http://www.dianping.com/chengdu/ch10/r1597'):
        renmin.append(True)
    else:
        renmin.append(False)

df['地区'][renmin]  = '人民公园'
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
jinsha =[]
for i in df['地区']:
    if i.__contains__('http://www.dianping.com/chengdu/ch10/r1586'):
        jinsha.append(True)
    else:
        jinsha.append(False)

df['地区'][jinsha]  = '金沙'
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
jianshelu =[]
for i in df['地区']:
    if i.__contains__('http://www.dianping.com/chengdu/ch10/r1974'):
        jianshelu.append(True)
    else:
        jianshelu.append(False)

df['地区'][jianshelu]  = '建设路'
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
yulin =[]
for i in df['地区']:
    if i.__contains__('http://www.dianping.com/chengdu/ch10/r1578'):
        yulin.append(True)
    else:
        yulin.append(False)

df['地区'][yulin]  = '玉林'
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
luomashi =[]
for i in df['地区']:
    if i.__contains__('http://www.dianping.com/chengdu/ch10/r1604'):
        luomashi.append(True)
    else:
        luomashi.append(False)

df['地区'][luomashi]  = '骡马市'
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
shuangnan =[]
for i in df['地区']:
    if i.__contains__('http://www.dianping.com/chengdu/ch10/r1591'):
        shuangnan.append(True)
    else:
        shuangnan.append(False)

df['地区'][shuangnan]  = '双楠'
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
tongzilin =[]
for i in df['地区']:
    if i.__contains__('http://www.dianping.com/chengdu/ch10/r1596'):
        tongzilin.append(True)
    else:
        tongzilin.append(False)

df['地区'][tongzilin]  = '桐梓林'
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
jiuyanqiao =[]
for i in df['地区']:
    if i.__contains__('http://www.dianping.com/chengdu/ch10/r7766'):
        jiuyanqiao.append(True)
    else:
        jiuyanqiao.append(False)

df['地区'][jiuyanqiao]  = '九眼桥'
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
sichuanshida =[]
for i in df['地区']:
    if i.__contains__('http://www.dianping.com/chengdu/ch10/r1602'):
        sichuanshida.append(True)
    else:
        sichuanshida.append(False)

df['地区'][sichuanshida]  = '四川师大'
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
dufucaotang =[]
for i in df['地区']:
    if i.__contains__('http://www.dianping.com/chengdu/ch10/r1583'):
        dufucaotang.append(True)
    else:
        dufucaotang.append(False)

df['地区'][dufucaotang]  = '杜甫草堂'
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
xinanjiaoda =[]
for i in df['地区']:
    if i.__contains__('http://www.dianping.com/chengdu/ch10/r1581'):
        xinanjiaoda.append(True)
    else:
        xinanjiaoda.append(False)

df['地区'][xinanjiaoda]  = '西南交大'
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
taishenglu =[]
for i in df['地区']:
    if i.__contains__('http://www.dianping.com/chengdu/ch10/r7770'):
        taishenglu.append(True)
    else:
        taishenglu.append(False)

df['地区'][taishenglu]  = '太升路'
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
niushikou =[]
for i in df['地区']:
    if i.__contains__('http://www.dianping.com/chengdu/ch10/r1579'):
        niushikou.append(True)
    else:
        niushikou.append(False)

df['地区'][niushikou]  = '牛市口'
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
shuangliu =[]
for i in df['地区']:
    if i.__contains__('http://www.dianping.com/shuangliu/'):
        shuangliu.append(True)
    else:
        shuangliu.append(False)

df['地区'][shuangliu]  = '双流'
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
dujiangyan =[]
for i in df['地区']:
    if i.__contains__('http://www.dianping.com/dujiangyan/'):
        dujiangyan.append(True)
    else:
        dujiangyan.append(False)

df['地区'][dujiangyan]  = '都江堰'
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
wenjiang =[]
for i in df['地区']:
    if i.__contains__('http://www.dianping.com/wenjiang/'):
        wenjiang.append(True)
    else:
        wenjiang.append(False)

df['地区'][wenjiang]  = '温江'
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df['地区']
# Out:
# 0                                              春熙路
# 1                                             宽窄巷子
# 2                                              春熙路
# 3                                              盐市口
# 4                                              武侯祠
# 5                                              春熙路
# 6      http://www.dianping.com/chengdu/ch10/r12365
# 7                                              大慈寺
# 8                                              春熙路
# 9       http://www.dianping.com/chengdu/ch10/r7763
# 10                                              玉林
# 11                                              玉林
# 12                                             武侯祠
# 13                                              玉林
# 14                                             春熙路
# 15                                            宽窄巷子
# 16                                            杜甫草堂
# 17                                            宽窄巷子
# 18                                             桐梓林
# 19                                             大慈寺
# 20                                             春熙路
# 21                                             高新区
# 22                                            科华北路
# 23     http://www.dianping.com/chengdu/ch10/r12372
# 24                                             太升路
# 25                                             春熙路
# 26                                            宽窄巷子
# 27                                             高新区
# 28                                             大慈寺
# 29                                             桐梓林
#                           ...
# 720                                            高新区
# 721                                            高新区
# 722    http://www.dianping.com/jintang/ch10/r27624
# 723                                            桐梓林
# 724                                             双流
# 725                                             双楠
# 726     http://www.dianping.com/chengdu/ch10/r1588
# 727     http://www.dianping.com/chengdu/ch10/r1599
# 728                                            高新区
# 729     http://www.dianping.com/chengdu/ch10/r1580
# 730    http://www.dianping.com/chengdu/ch10/r85538
# 731                                           科华北路
# 732     http://www.dianping.com/chengdu/ch10/r1590
# 733                                             光华
# 734     http://www.dianping.com/chengdu/ch10/r1972
# 735                                           杜甫草堂
# 736                                             金沙
# 737                                            建设路
# 738     http://www.dianping.com/chengdu/ch10/r1972
# 739    http://www.dianping.com/chengdu/ch10/r30791
# 740                                           杜甫草堂
# 741                                             双楠
# 742                                             玉林
# 743     http://www.dianping.com/chengdu/ch10/r8949
# 744                                            都江堰
# 745                                            牛市口
# 746                                             双流
# 747                                            牛市口
# 748     http://www.dianping.com/chengdu/ch10/r8951
# 749    http://www.dianping.com/chengdu/ch10/r70611
# Name: 地区, Length: 750, dtype: object

# %%
place_df = df.groupby('地区').size()
for k in place_df.index:
    print(k, place_df[k])
# Out:
# http://www.dianping.com/chengdu/ch10/r12315 1
# http://www.dianping.com/chengdu/ch10/r12317 2
# http://www.dianping.com/chengdu/ch10/r12361 3
# http://www.dianping.com/chengdu/ch10/r12362 2
# http://www.dianping.com/chengdu/ch10/r12363 3
# http://www.dianping.com/chengdu/ch10/r12365 4
# http://www.dianping.com/chengdu/ch10/r12366 4
# http://www.dianping.com/chengdu/ch10/r12367 2
# http://www.dianping.com/chengdu/ch10/r12368 2
# http://www.dianping.com/chengdu/ch10/r12370 1
# http://www.dianping.com/chengdu/ch10/r12371 7
# http://www.dianping.com/chengdu/ch10/r12372 1
# http://www.dianping.com/chengdu/ch10/r12373 1
# http://www.dianping.com/chengdu/ch10/r1580 6
# http://www.dianping.com/chengdu/ch10/r1582 1
# http://www.dianping.com/chengdu/ch10/r1584 2
# http://www.dianping.com/chengdu/ch10/r1588 8
# http://www.dianping.com/chengdu/ch10/r1590 4
# http://www.dianping.com/chengdu/ch10/r1599 8
# http://www.dianping.com/chengdu/ch10/r1972 3
# http://www.dianping.com/chengdu/ch10/r1973 1
# http://www.dianping.com/chengdu/ch10/r23124 1
# http://www.dianping.com/chengdu/ch10/r23125 4
# http://www.dianping.com/chengdu/ch10/r30783 2
# http://www.dianping.com/chengdu/ch10/r30788 2
# http://www.dianping.com/chengdu/ch10/r30790 1
# http://www.dianping.com/chengdu/ch10/r30791 2
# http://www.dianping.com/chengdu/ch10/r35 7
# http://www.dianping.com/chengdu/ch10/r36 1
# http://www.dianping.com/chengdu/ch10/r37 10
# http://www.dianping.com/chengdu/ch10/r4956 1
# http://www.dianping.com/chengdu/ch10/r5893 3
# http://www.dianping.com/chengdu/ch10/r5895 1
# http://www.dianping.com/chengdu/ch10/r66694 1
# http://www.dianping.com/chengdu/ch10/r70292 1
# http://www.dianping.com/chengdu/ch10/r70537 2
# http://www.dianping.com/chengdu/ch10/r70611 9
# http://www.dianping.com/chengdu/ch10/r70677 1
# http://www.dianping.com/chengdu/ch10/r7760 9
# http://www.dianping.com/chengdu/ch10/r7761 1
# http://www.dianping.com/chengdu/ch10/r7763 6
# http://www.dianping.com/chengdu/ch10/r7768 9
# http://www.dianping.com/chengdu/ch10/r7772 2
# http://www.dianping.com/chengdu/ch10/r7901 3
# http://www.dianping.com/chengdu/ch10/r80885 6
# http://www.dianping.com/chengdu/ch10/r85532 1
# http://www.dianping.com/chengdu/ch10/r85538 5
# http://www.dianping.com/chengdu/ch10/r85837 5
# http://www.dianping.com/chengdu/ch10/r87687 1
# http://www.dianping.com/chengdu/ch10/r87795 1
# http://www.dianping.com/chengdu/ch10/r87799 1
# http://www.dianping.com/chengdu/ch10/r87803 1
# http://www.dianping.com/chengdu/ch10/r8948 2
# http://www.dianping.com/chengdu/ch10/r8949 5
# http://www.dianping.com/chengdu/ch10/r8950 4
# http://www.dianping.com/chengdu/ch10/r8951 1
# http://www.dianping.com/chengdu/ch10/r8952 2
# http://www.dianping.com/chengdu/ch10/r9347 3
# http://www.dianping.com/chongzhou/ch10/r27623 3
# http://www.dianping.com/chongzhou/ch10/r87816 1
# http://www.dianping.com/dayi/ch10/r27625 1
# http://www.dianping.com/dayi/ch10/r75167 1
# http://www.dianping.com/dayi/ch10/r87875 1
# http://www.dianping.com/jintang/ch10/r27624 1
# http://www.dianping.com/pixian/ch10/r23140 2
# http://www.dianping.com/pixian/ch10/r4966 6
# http://www.dianping.com/pixian/ch10/r70740 3
# http://www.dianping.com/pixian/ch10/r70741 1
# http://www.dianping.com/pixian/ch10/r75357 1
# http://www.dianping.com/qingbaijiang/ch10/r27619 1
# http://www.dianping.com/qingchengshan/ch10/r64742 2
# http://www.dianping.com/qingchengshan/ch10/r71729 2
# http://www.dianping.com/xindu/ch10/r23128 1
# http://www.dianping.com/xindu/ch10/r23130 1
# http://www.dianping.com/xindu/ch10/r4958 1
# http://www.dianping.com/xindu/ch10/r70772 1
# http://www.dianping.com/xindu/ch10/r72106 1
# http://www.dianping.com/xinjin/ch10/r75769 1
# 九眼桥 17
# 人民公园 6
# 光华 16
# 双楠 20
# 双流 39
# 四川师大 14
# 大慈寺 7
# 太升路 11
# 宽窄巷子 27
# 建设路 15
# 春熙路 50
# 杜甫草堂 13
# 桐梓林 26
# 武侯祠 16
# 温江 13
# 牛市口 10
# 玉林 12
# 盐市口 9
# 磨子桥 7
# 科华北路 22
# 西南交大 11
# 跳伞塔 5
# 都江堰 11
# 金沙 7
# 锦华万达 13
# 骡马市 5
# 高新区 133

# %%
df
# Out:
#      Unnamed: 0                   店名   口味   环境   服务  \
# 0             0              马旺子·川小馆  8.5  9.1  8.9
# 1             1           成都吃客(奎星楼店)  8.9  7.6  8.6
# 2             2           成都吃客(致民路店)  8.9  8.8  9.0
# 3             3           饕林餐厅(春熙路店)  9.0  8.8  8.9
# 4             4           饕林餐厅(武侯祠店)  9.0  9.1  9.1
# 5             5        饕林·约饭(太古里小院店)  9.1  9.0  9.1
# 6             6       鸡毛店(温江老字号李家沱店)  9.1  8.7  8.6
# 7             7         柴门饭儿(远洋太古里店)  7.9  8.4  7.8
# 8             8    汤公汤婆煲汤治愈所(IFS旗舰店)  9.0  9.1  9.0
# 9             9          陶德砂锅居(蜀汉路店)  9.0  9.0  9.2
# 10           10        鸡毛店(温江老字号玉林店)  9.0  8.9  8.5
# 11           11             王小蚝(玉林店)  9.1  9.0  9.1
# 12           12                  钦善斋  8.8  8.9  8.7
# 13           13         青龙正街饭店(蓉城总店)  9.0  8.5  9.1
# 14           14         烤匠麻辣烤鱼(IFS店)  8.8  8.9  8.5
# 1                                           宽窄巷子
# 2                                            春熙路
# 3                                            盐市口
# 4                                            武侯祠
# 5                                            春熙路
# 6    http://www.dianping.com/chengdu/ch10/r12365
# 7                                            大慈寺
# 8                                            春熙路
# 9     http://www.dianping.com/chengdu/ch10/r7763
# 10                                            玉林
# 11                                            玉林
# 12                                           武侯祠
# 13                                            玉林
# 14                                           春熙路
# 15                                          宽窄巷子
# 16                                          杜甫草堂
# 17                                          宽窄巷子
# 18                                           桐梓林
# 19                                           大慈寺
# 20                                           春熙路
# 21                                           高新区
# 22                                          科华北路
# 23   http://www.dianping.com/chengdu/ch10/r12372
# 24                                           太升路
# 25                                           春熙路
# 26                                          宽窄巷子
# 27                                           高新区
# 28                                           大慈寺
# 29                                           桐梓林
# ..                                           ...
# 720                                          高新区
# 721                                          高新区
# 722  http://www.dianping.com/jintang/ch10/r27624
# 723                                          桐梓林
# 724                                           双流
# 725                                           双楠
# 726   http://www.dianping.com/chengdu/ch10/r1588
# 727   http://www.dianping.com/chengdu/ch10/r1599
# 728                                          高新区
# 729   http://www.dianping.com/chengdu/ch10/r1580
# 730  http://www.dianping.com/chengdu/ch10/r85538
# 731                                         科华北路
# 732   http://www.dianping.com/chengdu/ch10/r1590
# 733                                           光华
# 734   http://www.dianping.com/chengdu/ch10/r1972
# 735                                         杜甫草堂
# 736                                           金沙
# 737                                          建设路
# 738   http://www.dianping.com/chengdu/ch10/r1972
# 739  http://www.dianping.com/chengdu/ch10/r30791
# 740                                         杜甫草堂
# 741                                           双楠
# 742                                           玉林
# 743   http://www.dianping.com/chengdu/ch10/r8949
# 744                                          都江堰
# 745                                          牛市口
# 746                                           双流
# 747                                          牛市口
# 748   http://www.dianping.com/chengdu/ch10/r8951
# 749  http://www.dianping.com/chengdu/ch10/r70611
#
# [750 rows x 6 columns]

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
df.head(10)
# Out:
#    Unnamed: 0                 店名   口味   环境   服务  \
# 0           0            马旺子·川小馆  8.5  9.1  8.9
# 1           1         成都吃客(奎星楼店)  8.9  7.6  8.6
# 2           2         成都吃客(致民路店)  8.9  8.8  9.0
# 3           3         饕林餐厅(春熙路店)  9.0  8.8  8.9
# 4           4         饕林餐厅(武侯祠店)  9.0  9.1  9.1
# 5           5      饕林·约饭(太古里小院店)  9.1  9.0  9.1
# 6           6     鸡毛店(温江老字号李家沱店)  9.1  8.7  8.6
# 7           7       柴门饭儿(远洋太古里店)  7.9  8.4  7.8
# 8           8  汤公汤婆煲汤治愈所(IFS旗舰店)  9.0  9.1  9.0
# 9           9        陶德砂锅居(蜀汉路店)  9.0  9.0  9.2
#
#                                             地区
# 0                                          春熙路
# 1                                         宽窄巷子
# 2                                          春熙路
# 3                                          盐市口
# 4                                          武侯祠
# 5                                          春熙路
# 6  http://www.dianping.com/chengdu/ch10/r12365
# 7                                          大慈寺
# 8                                          春熙路
# 9   http://www.dianping.com/chengdu/ch10/r7763

# %%
pd.DataFrame.to_csv(df, '成都川菜商区改名.csv')

# %%
pd_sichuanchuancai = pd.DataFrame.from(shop, orient ='index').transpose()
