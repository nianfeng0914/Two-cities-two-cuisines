# %%
import pandas as pd 

csv_file = "长沙合并.csv"
gapminder = pd.read_csv(csv_file)

# %%
print(type(gapminder))
gapminder.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
#    Unnamed: 0  类型                店名   口味   环境   服务    地区
# 0           0  湘菜  钰湘宴·剁椒鱼头(河西岳麓总店)  8.5  8.9  8.6   桐梓坡
# 1           1  湘菜        天水阁餐厅(岳麓店)  8.9  8.8  9.1   银盆岭
# 2           2  湘菜        潘记虾尾(新开铺店)  8.3  9.1  7.6  五一广场
# 3           3  湘菜       霸王虾(湘江世纪城店)  7.3  8.3  7.3   坡子街
# 4           4  湘菜       新哥大排挡(润泽园店)  8.9  8.3  7.7   坡子街

# %%
gapminder.shape
# Out:
# (1201, 7)

# %%
gapminder.columns
# Out:
# Index(['Unnamed: 0', '类型', '店名', '口味', '环境', '服务', '地区'], dtype='object')

# %%
gapminder.describe()
# Out:
#         Unnamed: 0           口味           环境           服务
# count  1201.000000  1045.000000  1045.000000  1045.000000
# mean    318.359700     7.514928     7.580670     7.492632
# std     202.269145     0.509552     0.563335     0.511003
# min       0.000000     6.200000     5.300000     5.500000
# 25%     150.000000     7.200000     7.200000     7.200000
# 50%     300.000000     7.400000     7.500000     7.400000
# 75%     450.000000     7.800000     7.900000     7.700000
# max     749.000000     9.100000     9.400000     9.200000

# %%
gapminder[gapminder['类型']=="湘菜"]
# Out:
#      Unnamed: 0  类型                    店名   口味   环境   服务  \
# 0             0  湘菜      钰湘宴·剁椒鱼头(河西岳麓总店)  8.5  8.9  8.6
# 1             1  湘菜            天水阁餐厅(岳麓店)  8.9  8.8  9.1
# 2             2  湘菜            潘记虾尾(新开铺店)  8.3  9.1  7.6
# 3             3  湘菜           霸王虾(湘江世纪城店)  7.3  8.3  7.3
# 4             4  湘菜           新哥大排挡(润泽园店)  8.9  8.3  7.7
# 5             5  湘菜             乡村吊锅(茂华店)  7.3  9.0  7.8
# 6             6  湘菜                兄弟宁乡蛇城  7.4  8.3  7.5
# 7             7  湘菜              新长福(国贸店)  7.3  9.1  8.6
# 8             8  湘菜       钰湘宴·剁椒鱼头(解放西路店)  7.9  8.8  7.1
# 9             9  湘菜            映象潇湘(省政府店)  8.5  8.6  8.9
# 10           10  湘菜                 锦橡中餐馆  8.7  9.0  8.0
# 11           11  湘菜        龙锦人家私房菜(五一庙街店)  7.8  8.5  8.2
# 12           12  湘菜         君庭•山里小厨(梅溪湖店)  8.7  9.0  8.8
# 13           13  湘菜          费大厨辣椒炒肉(悦方店)  8.0  8.9  8.7
# 14           14  湘菜            食鉴家(红橡华园店)  8.9  8.2  9.0
# 15           15  湘菜               瓦舍酒香柴火鸡  8.6  7.5  8.5
# 16           16  湘菜             大鸽饭(湘府路店)  8.5  8.4  8.2
# 17           17  湘菜       钰湘宴·剁椒鱼头(解放西路店)  8.9  8.8  8.9
# 18           18  湘菜        张氏父子常德肠子馆(红星店)  8.7  7.4  7.9
# 19           19  湘菜                   桃源集  8.1  8.8  8.2
# 20           20  湘菜         严厨老坛酸菜鱼(左家塘店)  8.7  8.9  9.0
# 21           21  湘菜                山伴庭院餐厅  8.4  8.7  8.4
# 22           22  湘菜            伍厚德堂(九龙仓店)  7.3  8.3  7.5
# 23           23  湘菜                  湖湘一号  8.1  9.0  7.6
# 24           24  湘菜        天上人间旋转餐厅(友谊宾馆)  8.2  9.1  8.8
# 25           25  湘菜  哇鳝 韵味湘菜(华远facemore店)  8.5  9.1  8.8
# 26           26  湘菜                    杂咖  8.2  9.0  8.6
# 27           27  湘菜        炊烟时代小炒黄牛肉(悦方店)  8.5  8.7  9.2
# 28           28  湘菜      长沙北辰洲际酒店(栀味轩中餐厅)  8.1  9.1  9.1
# 29           29  湘菜        乐兮小酒馆(华创国际广场店)  8.1  9.0  8.7
# ..          ...  ..                   ...  ...  ...  ...
# 720         720  湘菜            福临门酒楼(运达店)  7.3  7.3  7.1
# 721         721  湘菜                 爱善湘餐厅  7.1  7.4  6.8
# 722         722  湘菜                 百果园农庄  6.7  6.6  6.6
# 723         723  湘菜              梦之厨(咸嘉店)  7.5  7.6  7.7
# 724         724  湘菜            胡记饭铺(杉木冲店)  7.0  7.0  7.0
# 725         725  湘菜                尚煨精品湘菜  7.2  7.3  7.3
# 726         726  湘菜                青瓷柴火鱼味  7.3  7.2  7.2
# 727         727  湘菜                  丁厨当家  7.1  7.1  7.1
# 728         728  湘菜                 镇昌一饭店  7.6  7.5  7.5
# 729         729  湘菜                  梓红酒家  7.5  7.3  7.4
# 730         730  湘菜                  桂园禅院  8.1  8.7  8.6
# 731         731  湘菜     火那师傅.农家火锅私房菜(涉外店)  7.4  7.5  7.5
# 732         732  湘菜          金水湾食府(城南西路店)  7.1  7.2  7.0
# 733         733  湘菜             芳食记生态主题餐厅  7.3  7.3  7.6
# 734         734  湘菜             麦田无限(万达店)  7.0  7.3  7.3
# 735         735  湘菜                  七品湘厨  7.1  7.2  7.2
# 736         736  湘菜                  悦禧小厨  7.3  7.3  7.3
# 737         737  湘菜                捌栋屋家菜馆  7.4  7.3  7.0
# 738         738  湘菜             食桌(富兴旺角店)  7.2  7.4  7.4
# 739         739  湘菜               味你好主题餐厅  7.4  7.4  7.5
# 740         740  湘菜            五溪老灶柴火鸡柴火鹅  7.1  7.1  7.1
# 741         741  湘菜                  永州味道  7.3  7.4  7.2
# 742         742  湘菜          湘侬寨三大碗(刘家冲店)  7.6  7.6  7.4
# 743         743  湘菜             花之林(林科大店)  7.5  7.4  7.3
# 744         744  湘菜                 员外胡萝卜  7.2  7.2  7.3
# 745         745  湘菜             食来实往(周南店)  7.2  7.2  7.2
# 746         746  湘菜             力力渔港(星沙店)  6.7  6.9  6.9
# 747         747  湘菜                小桥音乐餐厅  7.0  7.3  7.3
# 748         748  湘菜          食味风味餐厅(银盆岭店)  7.6  7.7  7.6
# 749         749  湘菜                 娘屋里呷饭  7.4  7.4  7.2
#
#                                                地区
# 0                                             桐梓坡
# 1                                             银盆岭
# 2                                            五一广场
# 3                                             坡子街
# 4                                             坡子街
# 5                                           湘江世纪城
# 6                                              高桥
# 7                                             新开铺
# 8                                             天心阁
# 9                                              麓谷
# 10                                            咸嘉湖
# 11                                           新省政府
# 12                                            梅溪湖
# 13    http://www.dianping.com/changsha/ch10/r8252
# 14                                         浏阳河风光带
# 15                                            新开铺
# 16                                             红星
# 17                                           五一广场
# 18                                             红星
# 19   http://www.dianping.com/changsha/ch10/r70517
# 20    http://www.dianping.com/changsha/ch10/r6032
# 21     http://www.dianping.com/changsha/ch10/r300
# 22                                            坡子街
# 23                                            坡子街
# 24                                           五一广场
# 25                                            坡子街
# 26    http://www.dianping.com/changsha/ch10/r7958
# 27                                            坡子街
# 28   http://www.dianping.com/changsha/ch10/r70517
# 29    http://www.dianping.com/changsha/ch10/r6029
# ..                                            ...
# 720                                            高桥
# 721    http://www.dianping.com/changsha/ch10/r301
# 722  http://www.dianping.com/changsha/ch10/r28487
# 723                                           桐梓坡
# 724                                          新省政府
# 725                                           新开铺
# 726    http://www.dianping.com/changsha/ch10/r302
# 727  http://www.dianping.com/changsha/ch10/r12169
# 728   http://www.dianping.com/changsha/ch10/r4641
# 729                                            东塘
# 730                                        涉外经济学院
# 731                                        涉外经济学院
# 732                                           天心阁
# 733  http://www.dianping.com/changsha/ch10/r12157
# 734                                          开福万达
# 735                                           四方坪
# 736  http://www.dianping.com/changsha/ch10/r24008
# 737                                        铁道/科林大
# 738    http://www.dianping.com/changsha/ch10/r300
# 739  http://www.dianping.com/changsha/ch10/r88514
# 740    http://www.dianping.com/changsha/ch10/r303
# 741                                           梅溪湖
# 742                                          新省政府
# 743                                        芙蓉南路沿线
# 744                                        涉外经济学院
# 745    http://www.dianping.com/changsha/ch10/r300
# 746                                           长沙县
# 747   http://www.dianping.com/changsha/ch10/r8273
# 748                                           银盆岭
# 749    http://www.dianping.com/changsha/ch10/r300
#
# [750 rows x 7 columns]

# %%
from pandas import *

# %%
table1 = pivot_table(gapminder, values='口味', columns=['类型'],aggfunc=np.mean)
print(table1)
# Out:
# 类型        川菜        湘菜
# 口味  7.201356  7.638267

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
table1.plot(kind = 'bar', rot = 0, title = 'Taste Scores of Chuancai, Xiangcai in Changsha')
plt.show()
print(table1)
# Out:
# 类型        川菜        湘菜
# 口味  7.201356  7.638267

# %%
table2 = pivot_table(gapminder, values='环境', columns=['类型'],aggfunc=np.mean)
table2.plot(kind = 'bar', rot = 0,title = 'Environment Scores of Chuancai, Xiangcai in Changsha')
plt.show()
print(table2)
# Out:
# 类型        川菜        湘菜
# 环境  7.214915  7.724533

# %%
table3 = pivot_table(gapminder, values='服务', columns=['类型'],aggfunc=np.mean)
table3.plot(kind = 'bar', rot = 0,title = 'Servoice Scores of Chuancai, Xiangcai in Changsha')
plt.show()
print(table3)
# Out:
# 类型        川菜        湘菜
# 服务  7.226441  7.597333

# %%
df=pd.read_csv("长沙合并.csv")
gp=df.groupby(by=['类型','地区'])
gp.size()
# Out:
# 类型  地区
# 川菜  http://www.dianping.com/changsha/ch10/r12145     2
#     http://www.dianping.com/changsha/ch10/r12146     8
#     http://www.dianping.com/changsha/ch10/r12148     1
#     http://www.dianping.com/changsha/ch10/r12149     1
#     http://www.dianping.com/changsha/ch10/r12150     2
#     http://www.dianping.com/changsha/ch10/r12151     1
#     http://www.dianping.com/changsha/ch10/r12157     2
#     http://www.dianping.com/changsha/ch10/r12160     1
#     http://www.dianping.com/changsha/ch10/r12162     5
#     http://www.dianping.com/changsha/ch10/r12163     5
#     http://www.dianping.com/changsha/ch10/r12166     2
#     http://www.dianping.com/changsha/ch10/r12167     2
#     http://www.dianping.com/changsha/ch10/r12168     4
#     http://www.dianping.com/changsha/ch10/r12169     4
#     http://www.dianping.com/changsha/ch10/r12170     5
#     http://www.dianping.com/changsha/ch10/r12171     5
#     http://www.dianping.com/changsha/ch10/r12172     1
#     http://www.dianping.com/changsha/ch10/r13406     1
#     http://www.dianping.com/changsha/ch10/r23991     7
#     http://www.dianping.com/changsha/ch10/r23997     3
#     http://www.dianping.com/changsha/ch10/r23999     2
#     http://www.dianping.com/changsha/ch10/r24002     1
#     http://www.dianping.com/changsha/ch10/r24004     4
#     http://www.dianping.com/changsha/ch10/r24005     1
#     http://www.dianping.com/changsha/ch10/r24006     1
#     http://www.dianping.com/changsha/ch10/r24007     5
#     http://www.dianping.com/changsha/ch10/r24008     4
#     http://www.dianping.com/changsha/ch10/r28486     2
#     http://www.dianping.com/changsha/ch10/r299      15
#     http://www.dianping.com/changsha/ch10/r300       6
#                                                     ..
# 湘菜  喜盈门                                             12
#     四方坪                                             12
#     坡子街                                             16
#     天心阁                                             13
#     开福万达                                            11
#     新开铺                                             13
#     新民路                                              5
#     新沙开发区                                           10
#     新省政府                                            14
#     桐梓坡                                             15
#     梅溪湖                                             15
#     河西大学城                                            5
#     浏阳河风光带                                           4
#     涉外经济学院                                          10
#     湘江世纪城                                           10
#     火车站                                              3
#     烈士公园                                             7
#     窑岭                                              11
#     红星                                              14
#     芙蓉南路沿线                                          10
#     袁家岭                                             13
#     观沙岭                                             13
#     解放西路                                             6
#     铁道/科林大                                           9
#     银盆岭                                             10
#     长沙县                                             16
#     马王堆                                              9
#     高桥                                              12
#     麓谷                                              11
#     黄兴路步行街                                          13
# Length: 223, dtype: int64

# %%
newdf=gp.size()
newdf.reset_index(name='times')
# Out:
#      类型                                            地区  times
# 0    川菜  http://www.dianping.com/changsha/ch10/r12145      2
# 1    川菜  http://www.dianping.com/changsha/ch10/r12146      8
# 2    川菜  http://www.dianping.com/changsha/ch10/r12148      1
# 3    川菜  http://www.dianping.com/changsha/ch10/r12149      1
# 4    川菜  http://www.dianping.com/changsha/ch10/r12150      2
# 5    川菜  http://www.dianping.com/changsha/ch10/r12151      1
# 6    川菜  http://www.dianping.com/changsha/ch10/r12157      2
# 7    川菜  http://www.dianping.com/changsha/ch10/r12160      1
# 8    川菜  http://www.dianping.com/changsha/ch10/r12162      5
# 9    川菜  http://www.dianping.com/changsha/ch10/r12163      5
# 10   川菜  http://www.dianping.com/changsha/ch10/r12166      2
# 11   川菜  http://www.dianping.com/changsha/ch10/r12167      2
# 12   川菜  http://www.dianping.com/changsha/ch10/r12168      4
# 13   川菜  http://www.dianping.com/changsha/ch10/r12169      4
# 14   川菜  http://www.dianping.com/changsha/ch10/r12170      5
# 15   川菜  http://www.dianping.com/changsha/ch10/r12171      5
# 16   川菜  http://www.dianping.com/changsha/ch10/r12172      1
# 17   川菜  http://www.dianping.com/changsha/ch10/r13406      1
# 18   川菜  http://www.dianping.com/changsha/ch10/r23991      7
# 19   川菜  http://www.dianping.com/changsha/ch10/r23997      3
# 20   川菜  http://www.dianping.com/changsha/ch10/r23999      2
# 21   川菜  http://www.dianping.com/changsha/ch10/r24002      1
# 22   川菜  http://www.dianping.com/changsha/ch10/r24004      4
# 23   川菜  http://www.dianping.com/changsha/ch10/r24005      1
# 24   川菜  http://www.dianping.com/changsha/ch10/r24006      1
# 25   川菜  http://www.dianping.com/changsha/ch10/r24007      5
# 26   川菜  http://www.dianping.com/changsha/ch10/r24008      4
# 27   川菜  http://www.dianping.com/changsha/ch10/r28486      2
# 28   川菜    http://www.dianping.com/changsha/ch10/r299     15
# 29   川菜    http://www.dianping.com/changsha/ch10/r300      6
# ..   ..                                           ...    ...
# 193  湘菜                                           喜盈门     12
# 194  湘菜                                           四方坪     12
# 195  湘菜                                           坡子街     16
# 196  湘菜                                           天心阁     13
# 197  湘菜                                          开福万达     11
# 198  湘菜                                           新开铺     13
# 199  湘菜                                           新民路      5
# 200  湘菜                                         新沙开发区     10
# 201  湘菜                                          新省政府     14
# 202  湘菜                                           桐梓坡     15
# 203  湘菜                                           梅溪湖     15
# 204  湘菜                                         河西大学城      5
# 205  湘菜                                        浏阳河风光带      4
# 206  湘菜                                        涉外经济学院     10
# 207  湘菜                                         湘江世纪城     10
# 208  湘菜                                           火车站      3
# 209  湘菜                                          烈士公园      7
# 210  湘菜                                            窑岭     11
# 211  湘菜                                            红星     14
# 212  湘菜                                        芙蓉南路沿线     10
# 213  湘菜                                           袁家岭     13
# 214  湘菜                                           观沙岭     13
# 215  湘菜                                          解放西路      6
# 216  湘菜                                        铁道/科林大      9
# 217  湘菜                                           银盆岭     10
# 218  湘菜                                           长沙县     16
# 219  湘菜                                           马王堆      9
# 220  湘菜                                            高桥     12
# 221  湘菜                                            麓谷     11
# 222  湘菜                                        黄兴路步行街     13
#
# [223 rows x 3 columns]

# %%
 df[ ~ df['地区'].str.contains('http') ]
# Out:
#      类型      地区  数量
# 74   川菜      东塘   5
# 75   川菜     中山亭   2
# 76   川菜    五一广场  14
# 77   川菜    体育新城   7
# 78   川菜     喜盈门   1
# 79   川菜     四方坪   5
# 80   川菜     坡子街   8
# 81   川菜     天心阁   3
# 82   川菜    开福万达   3
# 83   川菜     新开铺   2
# 84   川菜   新沙开发区   3
# 85   川菜    新省政府   6
# 86   川菜     桐梓坡   4
# 87   川菜     梅溪湖   5
# 88   川菜   河西大学城  10
# 89   川菜  涉外经济学院   4
# 90   川菜   湘江世纪城   5
# 91   川菜     火车站   1
# 92   川菜    烈士公园   1
# 93   川菜      窑岭   2
# 94   川菜      红星   6
# 95   川菜  芙蓉南路沿线   5
# 96   川菜     袁家岭   3
# 97   川菜     观沙岭   5
# 98   川菜    解放西路   4
# 99   川菜  铁道/科林大   5
# 100  川菜     银盆岭   5
# 101  川菜     长沙县  21
# 102  川菜     马王堆   5
# 103  川菜      高桥   8
# ..   ..     ...  ..
# 192  湘菜     喜盈门  12
# 193  湘菜     四方坪  12
# 194  湘菜     坡子街  16
# 195  湘菜     天心阁  13
# 196  湘菜    开福万达  11
# 197  湘菜     新开铺  13
# 198  湘菜     新民路   5
# 199  湘菜   新沙开发区  10
# 200  湘菜    新省政府  14
# 201  湘菜     桐梓坡  15
# 202  湘菜     梅溪湖  15
# 203  湘菜   河西大学城   5
# 204  湘菜  浏阳河风光带   4
# 205  湘菜  涉外经济学院  10
# 206  湘菜   湘江世纪城  10
# 207  湘菜     火车站   3
# 208  湘菜    烈士公园   7
# 209  湘菜      窑岭  11
# 210  湘菜      红星  14
# 211  湘菜  芙蓉南路沿线  10
# 212  湘菜     袁家岭  13
# 213  湘菜     观沙岭  13
# 214  湘菜    解放西路   6
# 215  湘菜  铁道/科林大   9
# 216  湘菜     银盆岭  10
# 217  湘菜     长沙县  16
# 218  湘菜     马王堆   9
# 219  湘菜      高桥  12
# 220  湘菜      麓谷  11
# 221  湘菜  黄兴路步行街  13
#
# [67 rows x 3 columns]

# %%
newdf.to_csv('test.csv')

# %%
df=pd.read_csv('test.csv',header=0)

# %%
df.columns='类型','地区','数量'
df_new=df[ ~ df['地区'].str.contains('http') ]

# %%
df_new.to_csv('长沙商区分布.csv')

# %%
csv_file = "长沙商区分布.csv"
gapminder = pd.read_csv(csv_file)
form1=gapminder[gapminder['类型']=="川菜"] 
form2=form1.sort_values(by='数量')
form_final=form2.tail(10)
form_final.to_csv('form_final_川菜.csv')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from pandas import *

chuancai = 'form_final_川菜.csv'
gapminder = pd.read_csv(chuancai)

table1 = pivot_table(gapminder, values='数量', columns=['地区'])
table1.plot(kind = 'bar', rot = 0,title = 'Chuan restaurant distribution in Changsha（top10）')
plt.show()

# %%
csv_file = "长沙商区分布.csv"
gapminder = pd.read_csv(csv_file)
form3=gapminder[gapminder['类型']=="湘菜"]

# %%
form4=form3.sort_values(by='数量')

# %%
form_final_1=form4.tail(10)
form_final_1.to_csv('form_final_湘菜.csv')

# %%
xiangcai = 'form_final_湘菜.csv'
gapminder_1 = pd.read_csv(xiangcai)

# %%
table2 = pivot_table(gapminder_1, values='数量', columns=['地区'])
table2.plot(kind = 'bar', rot = 0,title = ' restaurant distribution in Changsha（top10）')
plt.show()
